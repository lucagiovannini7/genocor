# %%
import os
import re

folder_path = r'C:\Users\Luca Giovannini\Documents\GitHub\genocor\transcripts\RWA-Seromba'

# Define a custom sorting function to sort based on numeric values
def custom_sort(file_name):
    if file_name.endswith(".txt"):
        # Extract the numeric part from the file name (assumes the numeric part is at the end)
        numeric_part = int(file_name.split('-')[-1].split('.')[0])
        return numeric_part
    else:
        return 0  # Return 0 for non-.txt files, which will keep them at the beginning

# List the files in the folder and sort them using the custom sorting function
file_list = os.listdir(folder_path)
file_list.sort(key=custom_sort)

# Define the regex pattern to match dates in the "30 JANUARY 2004" format
date_pattern = r'\d{1,2} [A-Z]+ \d{4}'

for filename in file_list:
    if filename.endswith(".txt"):
        file_path = os.path.join(folder_path, filename)
        try:
            with open(file_path, 'r') as file:
                content = file.read()
                match = re.search(date_pattern, content)
                if match:
                    print(f"{filename} : {match.group()}")
                else:
                    print(f"{filename} : No date found")
        except Exception as e:
            print(f"{filename} : Error - {e}")
# Out:
# ICTR-01-66-1.txt : 8 FEBRUARY 2002
# ICTR-01-66-2.txt : No date found
# ICTR-01-66-3.txt : No date found
# ICTR-01-66-4.txt : 21 SEPTEMBER 2004
# ICTR-01-66-5.txt : 22 SEPTEMBER 2004
# ICTR-01-66-6.txt : No date found
# ICTR-01-66-7.txt : No date found
# ICTR-01-66-8.txt : No date found
# ICTR-01-66-9.txt : No date found
# ICTR-01-66-10.txt : No date found
# ICTR-01-66-11.txt : No date found
# ICTR-01-66-12.txt : 5 OCTOBER 2004
# ICTR-01-66-13.txt : No date found
# ICTR-01-66-14.txt : No date found
# ICTR-01-66-15.txt : No date found
# ICTR-01-66-16.txt : 12 OCTOBER 2004
# ICTR-01-66-17.txt : 13 OCTOBER 2004
# ICTR-01-66-18.txt : No date found
# ICTR-01-66-19.txt : 15 OCTOBER 2004
# ICTR-01-66-20.txt : 18 OCTOBER 2004
# ICTR-01-66-21.txt : No date found
# ICTR-01-66-22.txt : No date found
# ICTR-01-66-23.txt : 21 OCTOBER 2004
# ICTR-01-66-24.txt : 22 OCTOBER 2004
# ICTR-01-66-25.txt : 19 JANUARY 2005
# ICTR-01-66-26.txt : 20 JANUARY 2005
# ICTR-01-66-27.txt : 24 JANUARY 2005
# ICTR-01-66-28.txt : No date found
# ICTR-01-66-29.txt : No date found
# ICTR-01-66-30.txt : No date found
# ICTR-01-66-31.txt : 10 MAY 2005
# ICTR-01-66-32.txt : No date found
# ICTR-01-66-33.txt : 27 OCTOBER 2005
# ICTR-01-66-34.txt : 31 OCTOBER 2005
# ICTR-01-66-35.txt : 1 NOVEMBER 2005
# ICTR-01-66-36.txt : 2 NOVEMBER 2005
# ICTR-01-66-37.txt : 7 NOVEMBER 2005
# ICTR-01-66-38.txt : 8 NOVEMBER 2005
# ICTR-01-66-39.txt : 9 NOVEMBER 2005
# ICTR-01-66-40.txt : 10 NOVEMBER 2005
# ICTR-01-66-41.txt : 14 NOVEMBER 2005
# ICTR-01-66-42.txt : 15 NOVEMBER 2005
# ICTR-01-66-43.txt : 16 NOVEMBER 2005
# ICTR-01-66-44.txt : 17 NOVEMBER 2005
# ICTR-01-66-45.txt : No date found
# ICTR-01-66-46.txt : 21 NOVEMBER 2005
# ICTR-01-66-47.txt : 22 NOVEMBER 2005
# ICTR-01-66-48.txt : No date found
# ICTR-01-66-49.txt : 24 NOVEMBER 2005
# ICTR-01-66-50.txt : 25 NOVEMBER 2005
# ICTR-01-66-51.txt : No date found
# ICTR-01-66-52.txt : 7 DECEMBER 2005
# ICTR-01-66-53.txt : No date found
# ICTR-01-66-54.txt : 23 MARCH 2006
# ICTR-01-66-55.txt : 24 MARCH 2006
# ICTR-01-66-56.txt : No date found
# ICTR-01-66-57.txt : No date found
# ICTR-01-66-58.txt : 29 MARCH 2006
# ICTR-01-66-59.txt : 30 MARCH 2006
# ICTR-01-66-60.txt : No date found
# ICTR-01-66-61.txt : 3 APRIL 2006
# ICTR-01-66-62.txt : 4 APRIL 2006
# ICTR-01-66-63.txt : 5 APRIL 2006
# ICTR-01-66-64.txt : 6 APRIL 2006
# ICTR-01-66-65.txt : 7 APRIL 2006
# ICTR-01-66-66.txt : 10 APRIL 2006
# ICTR-01-66-67.txt : 12 APRIL 2006
# ICTR-01-66-68.txt : 18 APRIL 2006
# ICTR-01-66-69.txt : 19 APRIL 2006
# ICTR-01-66-70.txt : 20 APRIL 2006
# ICTR-01-66-71.txt : 21 APRIL 2006
# ICTR-01-66-72.txt : 24 APRIL 2006
# ICTR-01-66-73.txt : 26 APRIL 2006
# ICTR-01-66-74.txt : 27 APRIL 2006
# ICTR-01-66-75.txt : 27 JUNE 2006
# ICTR-01-66-76.txt : 28 JUNE 2006
# ICTR-01-66-77.txt : 13 DECEMBER 2006
# ICTR-01-66-78.txt : 26 NOVEMBER 2007
